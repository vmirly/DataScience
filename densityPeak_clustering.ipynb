# %% [markdown]
# Clustering based on Density Peaks
# =======
#
# **Vahid Mirjalili, Data Scientist**
#
# # 1. Introduction
#
# Clustering algorithms has a wide range of applications. Several methods are proposed so far, and each method has drawbacks, for example in k-means clustering the knowledge of number of clusters is crucial, yet it doesn't provide a robust solution to datasets with clusters that have different sizes.
#
# In this article, an implementation of a novel clustering algorithm is provided, and applied to some synthetic datasets. <a href="http://www.sciencemag.org/content/344/6191/1492.abstract">See the reference.</a>.
#
# The most important feature of this algorithm is that it can automatically find the number of clusters.

# %%
## I plementation of Density Peak Clustering
### Vahid Mirjalili

import numpy as np

import urllib
import csv

# download the data
url = 'https://raw.githubusercontent.com/mirjalil/DataScience/blob/master/data/synthetic.6clust.csv'
content = urllib.urlopen(url)
content = content.read()

# save the datafile locally
with open('data/synthetic.csv', 'wb') as out:
    out.write(content)

# read data into numpy array
d = np.loadtxt("data/synthetic.csv", delimiter=',')
y = d[:2]
print(np.unique(y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-27008486dc6e> in <module>()
#      17
#      18 # read data into numpy array
# ---> 19 d = np.loadtxt("data/synthetic.6clust.csv", delimiter=',')
#      20 y = d[:2]
#      21 print(np.unique(y))
#
# /usr/local/lib/python2.7/dist-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     846                 vals = [vals[i] for i in usecols]
#     847             # Convert each value according to its column and store
# --> 848             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     849             # Then pack it according to the dtype's nesting
#     850             items = pack_items(items, packing)
#
# ValueError: could not convert string to float: <!DOCTYPE html>

# %% [markdown]
# In this dataset, 0 represents noise points, and others are considered as ground-truth cluster IDs. Next, we visulaize the dataset as below:

# %%
from matplotlib import pyplot as plt

# %matplotlib inline

plt.figure(figsize=(10,8))

for clustId,color in zip(range(0,7),('grey', 'blue', 'red', 'green', 'purple', 'orange', 'brown')):
    plt.scatter(x=d[:,0][d[:,2] == clustId],
                y=d[:,1][d[:,2] == clustId],
                color=color,
                marker='o',
                alpha=0.6
                )
plt.title('Clustered Dataset')
plt.xlabel('$x_1$', size=30)
plt.ylabel('$x_2$', size=30)

plt.tick_params(axis='both', which='major', labelsize=20)
plt.xlim(xmin=0, xmax=10)
plt.ylim(ymin=0, ymax=10)

plt.show()
